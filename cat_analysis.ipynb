# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"..\data\cats_dataset.csv")

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.columns
# Out:
# Index(['Breed', 'Age (Years)', 'Weight (kg)', 'Color', 'Gender'], dtype='object')

# %%
df.head()
# Out:
#               Breed  Age (Years)  Weight (kg)          Color  Gender
# 0      Russian Blue           19            7  Tortoiseshell  Female
# 1  Norwegian Forest           19            9  Tortoiseshell  Female
# 2         Chartreux            3            3          Brown  Female
# 3           Persian           13            6          Sable  Female
# 4           Ragdoll           10            8          Tabby    Male

# %%
df.dtypes
# Out:
# Breed          object
# Age (Years)     int64
# Weight (kg)     int64
# Color          object
# Gender         object
# dtype: object

# %%
print(df.describe())
# Out:
#        Age (Years)  Weight (kg)
# count  1000.000000   1000.00000
# mean     10.210000      5.55000
# std       5.535751      2.22676
# min       1.000000      2.00000
# 25%       5.000000      4.00000
# 50%      10.000000      6.00000
# 75%      15.000000      7.00000
# max      19.000000      9.00000

# %%
breed_counts = df['Breed'].value_counts()
sns.barplot(x=breed_counts.index, y=breed_counts.values)
plt.title('Breed Distribution')
plt.xlabel('Breed')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
color_counts = df['Color'].value_counts()
sns.barplot(x=color_counts.index, y=color_counts.values)
plt.title('Color Distribution')
plt.xlabel('Color')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
gender_counts = df['Gender'].value_counts()
sns.barplot(x=gender_counts.index, y=gender_counts.values)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['Age (Years)'], bins = 20, kde = True, color = 'black')
plt.title('Age Distribution')
plt.xlabel('Age (Years)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\pavan.DESKTOP-3J19QCT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df['Weight (kg)'], bins = 10, kde = True, color = 'black')
plt.title('Weight Distribution')
plt.xlabel('Weight (kg)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\pavan.DESKTOP-3J19QCT\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Bivariate Analysis

# %%
correlation = df['Age (Years)'].corr(df['Weight (kg)'])
print("Correlation between Age and Weight: ",correlation)
# Out:
# Correlation between Age and Weight:  -0.013601894376851222

# %%
sns.boxplot(x='Breed', y='Weight (kg)', data=df)
plt.title('Weight Distribution by Breed')
plt.xlabel('Breed')
plt.ylabel('Weight (kg)')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='Breed', y='Age (Years)', data=df)
plt.title('Age Distribution by Breed')
plt.xlabel('Breed')
plt.ylabel('Age (Years)')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='Gender', y='Weight (kg)', data=df)
plt.title('Weight Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Weight (kg)')
plt.show()

# %%
sns.boxplot(x='Gender', y='Age (Years)', data=df)
plt.title('Age Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Age (Years)')
plt.show()
